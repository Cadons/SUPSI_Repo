# %%
import plotly
import plotly.express as px
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("data/IMDb ratings.csv")

# %%
px.histogram(data_frame=df,x="median_vote").show()
# Out:
# <div>                            <div id="8f3f25b7-d584-4f17-990c-47727b5228a3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8f3f25b7-d584-4f17-990c-47727b5228a3")) {                    Plotly.newPlot(                        "8f3f25b7-d584-4f17-990c-47727b5228a3",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"median_vote=%{x}<br>count=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":[6.0,6.0,6.0,5.0,7.0,6.0,7.0,6.0,7.0,6.0,7.0,7.0,7.0,7.0,6.0,7.0,7.0,6.0,7.0,6.0,6.0,7.0,7.0,7.0,7.0,7.0,8.0,7.0,6.0,7.0,7.0,5.0,7.0,6.0,7.0,6.0,8.0,6.0,6.0,7.0,6.0,6.0,6.0,7.0,6.0,6.5,6.0,7.0,7.0,7.0,6.0,6.0,7.0,7.0,7.0,6.0,6
# ...
